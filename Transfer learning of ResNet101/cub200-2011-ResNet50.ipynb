# %%
import os
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras

pd.set_option('display.max_colwidth', 200)
# For tf.dataset
AUTO = tf.data.experimental.AUTOTUNE

# %%
# !pip install -q efficientnet

# %%
train = pd.read_csv('../input/cub200-2011-csv/train.csv')
test = pd.read_csv('../input/cub200-2011-csv/test.csv')

print(train.shape, test.shape)
train.head()
# Out:
# (5994, 10) (5794, 10)
#    ImageID      x     y  width  height  \
# 0        2  139.0  30.0  153.0   264.0
# 1        4  112.0  90.0  255.0   242.0
# 2        5   70.0  50.0  134.0   303.0
# 3        7    7.0  75.0  420.0   262.0
# 4        8   78.0  86.0  333.0   158.0
#
#                                                             filename  \
# 0      001.Black_footed_Albatross/Black_Footed_Albatross_0009_34.jpg
# 1      001.Black_footed_Albatross/Black_Footed_Albatross_0074_59.jpg
# 2      001.Black_footed_Albatross/Black_Footed_Albatross_0014_89.jpg
# 3     001.Black_footed_Albatross/Black_Footed_Albatross_0031_100.jpg
# 4  001.Black_footed_Albatross/Black_Footed_Albatross_0051_796103.jpg
#
#    Category  is_training                  Class Name  Label
# 0         1            1  001.Black_footed_Albatross      0
# 1         1            1  001.Black_footed_Albatross      0
# 2         1            1  001.Black_footed_Albatross      0
# 3         1            1  001.Black_footed_Albatross      0
# 4         1            1  001.Black_footed_Albatross      0

# %%
tpath = '../input/cub200/CUB_200_2011/images'
train_paths = train.filename.apply(lambda x: os.path.join(tpath, x))
train_paths.values
# Out:
# array(['../input/cub200/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0009_34.jpg',
#        '../input/cub200/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0074_59.jpg',
#        '../input/cub200/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0014_89.jpg',
#        ...,
#        '../input/cub200/CUB_200_2011/images/200.Common_Yellowthroat/Common_Yellowthroat_0094_190690.jpg',
#        '../input/cub200/CUB_200_2011/images/200.Common_Yellowthroat/Common_Yellowthroat_0037_190698.jpg',
#        '../input/cub200/CUB_200_2011/images/200.Common_Yellowthroat/Common_Yellowthroat_0049_190708.jpg'],
#       dtype=object)

# %%
from tensorflow.keras.utils import to_categorical

# convert to one-hot-encoding-labels
train_labels = to_categorical(train.Label)
train_labels.shape
# Out:
# (5994, 200)

# %%
tpath = '../input/cub200/CUB_200_2011/images'
test_paths = test.filename.apply(lambda x: os.path.join(tpath, x))
test_paths.values
# Out:
# array(['../input/cub200/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0046_18.jpg',
#        '../input/cub200/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0002_55.jpg',
#        '../input/cub200/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0085_92.jpg',
#        ...,
#        '../input/cub200/CUB_200_2011/images/200.Common_Yellowthroat/Common_Yellowthroat_0058_190958.jpg',
#        '../input/cub200/CUB_200_2011/images/200.Common_Yellowthroat/Common_Yellowthroat_0008_190703.jpg',
#        '../input/cub200/CUB_200_2011/images/200.Common_Yellowthroat/Common_Yellowthroat_0055_190967.jpg'],
#       dtype=object)

# %%
def decode_image(filename, label=None, image_size=(299, 299)):
    bits = tf.io.read_file(filename)
    image = tf.image.decode_jpeg(bits, channels=3)
    image = tf.cast(image, tf.float32) / 255.0
    image = tf.image.resize(image, image_size)
    
    if label is None:
        return image
    else:
        return image, label

# %%
def augment(image, label=None):
    image = tf.image.random_flip_left_right(image)
    
    if label is None:
        return image
    else:
        return image, label

# %%
batch_size = 32

train_dataset = (
    tf.data.Dataset
    .from_tensor_slices((train_paths, train_labels))
    .map(decode_image, num_parallel_calls=AUTO)
    .map(augment, num_parallel_calls=AUTO)
    .repeat()
    .shuffle(2048)
    .batch(batch_size)
    .prefetch(AUTO)
)

test_dataset = (tf.data.Dataset
        .from_tensor_slices(test_paths)
        .map(decode_image, num_parallel_calls=AUTO)
        .batch(batch_size)
)

# %%
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam

# from efficientnet.tfkeras import EfficientNetB2

model = tf.keras.Sequential([
        ResNet101(weights = 'imagenet', 
                       include_top = False,
                       input_shape = (299, 299, 3)),
        GlobalAveragePooling2D(),
        Dense(1024, activation = 'relu'),
        Dropout(0.25),
        Dense(512, activation = 'relu'),
        Dropout(0.25),
        Dense(200, activation = 'softmax')
])
    
model.compile(optimizer = 'sgd',
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])
    
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171450368/171446536 [==============================] - 2s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet101 (Model)            (None, 10, 10, 2048)      42658176
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 200)               102600
# =================================================================
# Total params: 45,383,752
# Trainable params: 45,278,408
# Non-trainable params: 105,344
# _________________________________________________________________

# %%
def Train_model(model, batch_size, EPOCHS):
    n_steps = train_labels.shape[0] // batch_size
    EPOCHS = EPOCHS
    
    Model = model
    history = Model.fit(train_dataset, 
                    steps_per_epoch = n_steps,
                    epochs = EPOCHS,
                    verbose = 1)
    return Model

# %%
batch_size = 32
EPOCHS = 50

def check(x, y):
    if x == y:
        return 1
    else:
        return 0
    
print('Training')
model = Train_model(model, batch_size, EPOCHS)
pred = model.predict(test_dataset, verbose=1)
    
test['Prediction'] = pred.argmax(axis=1)
test['Score'] = test.apply(lambda x: check(x['Prediction'], x['Label']), axis=1)
print('Test accuracy on iterations is ', 100 * test.Score.sum() / test.shape[0])
# Out:
# Training
# Epoch 1/50
# 187/187 [==============================] - 94s 505ms/step - loss: 5.1743 - accuracy: 0.0296
# Epoch 2/50
# 187/187 [==============================] - 94s 504ms/step - loss: 4.4297 - accuracy: 0.1156
# Epoch 3/50
# 187/187 [==============================] - 94s 503ms/step - loss: 3.3167 - accuracy: 0.2652
# Epoch 4/50
# 187/187 [==============================] - 94s 504ms/step - loss: 2.3931 - accuracy: 0.4083
# Epoch 5/50
# 187/187 [==============================] - 95s 506ms/step - loss: 1.6980 - accuracy: 0.5521
# Epoch 6/50
# 187/187 [==============================] - 94s 504ms/step - loss: 1.2604 - accuracy: 0.6591
# Epoch 7/50
# 187/187 [==============================] - 94s 503ms/step - loss: 0.9452 - accuracy: 0.7311
# Epoch 8/50
# 187/187 [==============================] - 94s 504ms/step - loss: 0.6948 - accuracy: 0.8045
# Epoch 9/50
# 187/187 [==============================] - 94s 504ms/step - loss: 0.5281 - accuracy: 0.8493
# Epoch 10/50
# 187/187 [==============================] - 94s 503ms/step - loss: 0.4249 - accuracy: 0.8830
# Epoch 11/50
# 187/187 [==============================] - 94s 504ms/step - loss: 0.3049 - accuracy: 0.9169
# Epoch 12/50
# 187/187 [==============================] - 94s 504ms/step - loss: 0.2462 - accuracy: 0.9362
# Epoch 13/50
# 187/187 [==============================] - 94s 503ms/step - loss: 0.1861 - accuracy: 0.9510
# Epoch 14/50
# 187/187 [==============================] - 94s 503ms/step - loss: 0.1460 - accuracy: 0.9659
# Epoch 15/50
# 187/187 [==============================] - 94s 504ms/step - loss: 0.1193 - accuracy: 0.9713
# Epoch 16/50
# 187/187 [==============================] - 94s 504ms/step - loss: 0.0920 - accuracy: 0.9776
# Epoch 17/50
# 187/187 [==============================] - 94s 503ms/step - loss: 0.0813 - accuracy: 0.9825
# Epoch 18/50
# 187/187 [==============================] - 94s 504ms/step - loss: 0.0730 - accuracy: 0.9836
# Epoch 19/50
# 187/187 [==============================] - 94s 503ms/step - loss: 0.0616 - accuracy: 0.9876
# Epoch 20/50
# 187/187 [==============================] - 94s 503ms/step - loss: 0.0565 - accuracy: 0.9875
# Epoch 21/50
# 187/187 [==============================] - 100s 534ms/step - loss: 0.0418 - accuracy: 0.9928
# Epoch 22/50
# 187/187 [==============================] - 94s 503ms/step - loss: 0.0370 - accuracy: 0.9930
# Epoch 23/50
# 187/187 [==============================] - 94s 505ms/step - loss: 0.0281 - accuracy: 0.9952
# Epoch 24/50
# 187/187 [==============================] - 94s 503ms/step - loss: 0.0287 - accuracy: 0.9940
# Epoch 25/50
# 187/187 [==============================] - 94s 504ms/step - loss: 0.0290 - accuracy: 0.9947
# Epoch 26/50
# 187/187 [==============================] - 94s 504ms/step - loss: 0.0180 - accuracy: 0.9973
# Epoch 27/50
# 187/187 [==============================] - 94s 504ms/step - loss: 0.0200 - accuracy: 0.9967
# Epoch 28/50
# 187/187 [==============================] - 94s 504ms/step - loss: 0.0223 - accuracy: 0.9958
# Epoch 29/50
# 187/187 [==============================] - 94s 503ms/step - loss: 0.0239 - accuracy: 0.9953
# Epoch 30/50
# 187/187 [==============================] - 94s 503ms/step - loss: 0.0233 - accuracy: 0.9965
# Epoch 31/50
# 187/187 [==============================] - 94s 503ms/step - loss: 0.0214 - accuracy: 0.9967
# Epoch 32/50
# 187/187 [==============================] - 94s 504ms/step - loss: 0.0183 - accuracy: 0.9977
# Epoch 33/50
# 187/187 [==============================] - 94s 503ms/step - loss: 0.0102 - accuracy: 0.9993
# Epoch 34/50
# 187/187 [==============================] - 94s 504ms/step - loss: 0.0119 - accuracy: 0.9988
# Epoch 35/50
# 187/187 [==============================] - 94s 504ms/step - loss: 0.0134 - accuracy: 0.9977
# Epoch 36/50
# 187/187 [==============================] - 94s 503ms/step - loss: 0.0105 - accuracy: 0.9988
# Epoch 37/50
# 187/187 [==============================] - 94s 503ms/step - loss: 0.0105 - accuracy: 0.9990
# Epoch 38/50
# 187/187 [==============================] - 94s 503ms/step - loss: 0.0108 - accuracy: 0.9983
# Epoch 39/50
# 187/187 [==============================] - 94s 503ms/step - loss: 0.0078 - accuracy: 0.9993
# Epoch 40/50
# 187/187 [==============================] - 94s 504ms/step - loss: 0.0088 - accuracy: 0.9987
# Epoch 41/50
# 187/187 [==============================] - 94s 503ms/step - loss: 0.0083 - accuracy: 0.9992
# Epoch 42/50
# 187/187 [==============================] - 94s 503ms/step - loss: 0.0146 - accuracy: 0.9975
# Epoch 43/50
# 187/187 [==============================] - 94s 502ms/step - loss: 0.0079 - accuracy: 0.9995
# Epoch 44/50
# 187/187 [==============================] - 94s 503ms/step - loss: 0.0076 - accuracy: 0.9992
# Epoch 45/50
# 187/187 [==============================] - 94s 502ms/step - loss: 0.0096 - accuracy: 0.9982
# Epoch 46/50
# 187/187 [==============================] - 94s 503ms/step - loss: 0.0110 - accuracy: 0.9980
# Epoch 47/50
# 187/187 [==============================] - 94s 503ms/step - loss: 0.0059 - accuracy: 0.9993
# Epoch 48/50
# 187/187 [==============================] - 94s 502ms/step - loss: 0.0055 - accuracy: 0.9998
# Epoch 49/50
# 187/187 [==============================] - 94s 502ms/step - loss: 0.0088 - accuracy: 0.9985
# Epoch 50/50
# 187/187 [==============================] - 94s 502ms/step - loss: 0.0067 - accuracy: 0.9990
# 182/182 [==============================] - 32s 174ms/step
# Test accuracy on iterations is  74.43907490507422

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(test.Label, test.Prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.77      0.78        30
#            1       0.81      0.70      0.75        30
#            2       0.70      0.93      0.80        28
#            3       0.78      0.83      0.81        30
#            4       1.00      0.86      0.92        14
#            5       0.83      0.91      0.87        11
#            6       0.88      0.96      0.92        23
#            7       0.70      0.78      0.74        18
#            8       0.67      0.55      0.60        29
#            9       0.84      0.90      0.87        30
#           10       0.57      0.43      0.49        30
#           11       0.91      0.81      0.86        26
#           12       0.88      0.73      0.80        30
#           13       0.85      0.97      0.91        30
#           14       0.92      0.82      0.87        28
#           15       0.96      0.89      0.93        28
#           16       0.87      0.96      0.91        27
#           17       0.94      1.00      0.97        15
#           18       0.69      0.76      0.72        29
#           19       0.74      0.69      0.71        29
#           20       0.87      0.90      0.89        30
#           21       0.79      0.85      0.81        26
#           22       0.42      0.55      0.48        29
#           23       0.79      0.68      0.73        22
#           24       0.46      0.43      0.45        30
#           25       0.82      0.77      0.79        30
#           26       0.52      0.47      0.49        30
#           27       0.90      0.93      0.92        29
#           28       0.39      0.37      0.38        30
#           29       0.31      0.53      0.40        30
#           30       0.63      0.57      0.60        30
#           31       0.73      0.70      0.71        23
#           32       0.53      0.55      0.54        29
#           33       0.93      0.93      0.93        29
#           34       0.88      0.97      0.92        30
#           35       0.91      0.97      0.94        30
#           36       0.45      0.48      0.47        29
#           37       0.69      0.67      0.68        30
#           38       0.32      0.41      0.36        29
#           39       0.54      0.63      0.58        30
#           40       0.88      0.77      0.82        30
#           41       0.93      0.87      0.90        30
#          123       0.76      0.86      0.81        29
#          124       0.86      0.66      0.75        29
#          125       0.74      0.57      0.64        30
#          126       0.65      0.67      0.66        30
#          127       0.73      0.73      0.73        30
#          128       0.67      0.60      0.63        30
#          129       0.68      0.63      0.66        30
#          130       0.54      0.73      0.62        30
#          131       0.93      0.90      0.92        30
#          132       0.84      0.90      0.87        30
#          133       0.96      0.87      0.91        30
#          134       0.41      0.53      0.46        30
#          135       0.79      0.63      0.70        30
#          136       0.56      0.50      0.53        30
#          137       0.92      0.77      0.84        30
#          138       0.75      0.90      0.82        30
#          139       0.87      0.87      0.87        30
#          140       0.57      0.45      0.50        29
#          141       0.62      0.43      0.51        30
#          142       0.43      0.40      0.41        30
#          143       0.25      0.23      0.24        30
#          144       0.45      0.43      0.44        30
#          145       0.36      0.47      0.41        30
#          146       0.63      0.63      0.63        30
#          147       1.00      0.90      0.95        30
#          148       0.76      0.86      0.81        29
#          149       0.80      0.67      0.73        30
#          150       0.87      0.95      0.91        21
#          151       0.77      0.67      0.71        30
#          152       0.50      0.76      0.60        29
#          153       0.83      0.63      0.72        30
#          154       0.58      0.73      0.65        30
#          155       0.74      0.77      0.75        30
#          156       0.67      0.48      0.56        29
#          157       0.76      0.83      0.79        30
#          158       0.97      0.97      0.97        30
#          159       0.97      1.00      0.98        29
#          160       0.74      0.83      0.78        30
#          161       0.88      0.73      0.80        30
#          162       0.96      0.87      0.91        30
#          163       0.96      0.90      0.93        30
#          164       0.84      0.87      0.85        30
#          165       0.96      0.90      0.93        29
#          166       0.81      0.73      0.77        30
#          167       0.85      0.79      0.82        29
#          168       0.89      0.86      0.88        29
#          169       0.85      0.77      0.81        30
#          170       0.80      0.80      0.80        30
#          171       0.63      0.87      0.73        30
#          172       0.57      0.57      0.57        30
#          173       0.91      0.70      0.79        30
#          174       0.59      0.80      0.68        30
#          175       0.84      0.90      0.87        30
#          176       0.71      0.90      0.79        30
#          177       0.83      0.77      0.80        26
#          178       0.60      0.52      0.56        29
#          179       0.85      0.73      0.79        30
#          180       0.90      0.93      0.92        29
#          181       0.73      0.80      0.76        30
#          182       0.80      0.80      0.80        30
#          183       0.77      0.80      0.79        30
#          184       0.78      0.93      0.85        30
#          185       0.96      0.83      0.89        30
#          186       0.83      0.95      0.88        20
#          187       0.94      1.00      0.97        30
#          188       0.91      1.00      0.95        30
#          189       0.96      0.90      0.93        29
#          190       0.93      0.83      0.88        30
#          191       0.94      0.97      0.95        30
#          192       0.62      0.43      0.51        30
#          193       0.81      0.97      0.88        30
#          194       0.75      0.70      0.72        30
#          195       0.66      0.70      0.68        30
#          196       0.62      0.67      0.65        30
#          197       0.88      0.73      0.80        30
#          198       0.89      0.80      0.84        30
#          199       0.93      0.90      0.92        30
#
#     accuracy                           0.74      5794
#    macro avg       0.76      0.75      0.75      5794
# weighted avg       0.76      0.74      0.74      5794
