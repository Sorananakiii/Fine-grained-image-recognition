# %%
import os
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
# For tf.dataset
AUTO = tf.data.experimental.AUTOTUNE

# %%
# !pip install -q efficientnet

# %%
train = pd.read_csv('../input/stanford-cars-csv-annotation/train.csv')
test = pd.read_csv('../input/stanford-cars-csv-annotation/test.csv')

print(train.shape, test.shape)
train.head()
# Out:
# (8144, 8) (8041, 8)
#    bbox_x1  bbox_y1  bbox_x2  bbox_y2  class_id   filename  \
# 0       39      116      569      375        14  00001.jpg
# 1       36      116      868      587         3  00002.jpg
# 2       85      109      601      381        91  00003.jpg
# 3      621      393     1484     1096       134  00004.jpg
# 4       14       36      133       99       106  00005.jpg
#
#                             class_name  category
# 0                  Audi TTS Coupe 2012        13
# 1                  Acura TL Sedan 2012         2
# 2           Dodge Dakota Club Cab 2007        90
# 3     Hyundai Sonata Hybrid Sedan 2012       133
# 4  Ford F-450 Super Duty Crew Cab 2012       105

# %%
train_path = "../input/stanford-cars-dataset/cars_train/cars_train"
train_dirs = os.listdir(train_path)
train_paths = []

# This would print all the files and directories
for file in train_dirs:
    train_paths.append(os.path.join(train_path, file))
    
train_paths = np.array(sorted(train_paths))
train_paths[:5]
# Out:
# array(['../input/stanford-cars-dataset/cars_train/cars_train/00001.jpg',
#        '../input/stanford-cars-dataset/cars_train/cars_train/00002.jpg',
#        '../input/stanford-cars-dataset/cars_train/cars_train/00003.jpg',
#        '../input/stanford-cars-dataset/cars_train/cars_train/00004.jpg',
#        '../input/stanford-cars-dataset/cars_train/cars_train/00005.jpg'],
#       dtype='<U62')

# %%
from tensorflow.keras.utils import to_categorical

# convert to one-hot-encoding-labels
train_labels = to_categorical(train.category)
train_labels.shape
# Out:
# (8144, 196)

# %%
test_path = "../input/stanford-cars-dataset/cars_test/cars_test"
test_dirs = os.listdir(test_path)
test_paths = []

# This would print all the files and directories
for file in test_dirs:
    test_paths.append(os.path.join(test_path, file))
    
test_paths = np.array(sorted(test_paths))
test_paths[:5]
# Out:
# array(['../input/stanford-cars-dataset/cars_test/cars_test/00001.jpg',
#        '../input/stanford-cars-dataset/cars_test/cars_test/00002.jpg',
#        '../input/stanford-cars-dataset/cars_test/cars_test/00003.jpg',
#        '../input/stanford-cars-dataset/cars_test/cars_test/00004.jpg',
#        '../input/stanford-cars-dataset/cars_test/cars_test/00005.jpg'],
#       dtype='<U60')

# %%
def decode_image(filename, label=None, image_size=(299, 299)):
    bits = tf.io.read_file(filename)
    image = tf.image.decode_jpeg(bits, channels=3)
    image = tf.cast(image, tf.float32) / 255.0
    image = tf.image.resize(image, image_size)
    
    if label is None:
        return image
    else:
        return image, label

# %%
def augment(image, label=None):
    image = tf.image.random_flip_left_right(image)
    
    if label is None:
        return image
    else:
        return image, label

# %%
batch_size = 32

train_dataset = (
    tf.data.Dataset
    .from_tensor_slices((train_paths, train_labels))
    .map(decode_image, num_parallel_calls=AUTO)
    .map(augment, num_parallel_calls=AUTO)
    .repeat()
    .shuffle(2048)
    .batch(batch_size)
    .prefetch(AUTO)
)

test_dataset = (tf.data.Dataset
        .from_tensor_slices(test_paths)
        .map(decode_image, num_parallel_calls=AUTO)
        .batch(batch_size)
)

# %%
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam

# from efficientnet.tfkeras import EfficientNetB2

model = tf.keras.Sequential([
        ResNet101(weights = 'imagenet', 
                       include_top = False,
                       input_shape = (299, 299, 3)),
        GlobalAveragePooling2D(),
        Dense(1024, activation = 'relu'),
        Dropout(0.25),
        Dense(512, activation = 'relu'),
        Dropout(0.25),
        Dense(196, activation = 'softmax')
])
    
model.compile(optimizer = 'sgd',
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])
    
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171450368/171446536 [==============================] - 10s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet101 (Model)            (None, 10, 10, 2048)      42658176
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 196)               100548
# =================================================================
# Total params: 45,381,700
# Trainable params: 45,276,356
# Non-trainable params: 105,344
# _________________________________________________________________

# %%
def Train_model(model, batch_size, EPOCHS):
    n_steps = train_labels.shape[0] // batch_size
    EPOCHS = EPOCHS
    
    Model = model
    history = Model.fit(train_dataset, 
                    steps_per_epoch = n_steps,
                    epochs = EPOCHS,
                    verbose = 1)
    return Model

# %%
# # Get training and test loss histories
# training_loss = history.history['accuracy']

# # Create count of the number of epochs
# epoch_count = range(1, len(training_loss) + 1)

# # Visualize loss history
# plt.plot(epoch_count, training_loss, 'r--')
# plt.legend(['Training acc'])
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.show()

# %%
batch_size = 32
EPOCHS = 50

def check(x, y):
    if x == y:
        return 1
    else:
        return 0
    
print('Training')
model = Train_model(model, batch_size, EPOCHS)
pred = model.predict(test_dataset, verbose=1)
    
test['Prediction'] = pred.argmax(axis=1)
test['Score'] = test.apply(lambda x: check(x['Prediction'], x['category']), axis=1)
print('Test accuracy on iterations is ', 100 * test.Score.sum() / test.shape[0])
# Out:
# Training
# Epoch 1/50
# 254/254 [==============================] - 130s 511ms/step - loss: 5.2478 - accuracy: 0.0116
# Epoch 2/50
# 254/254 [==============================] - 129s 509ms/step - loss: 4.6632 - accuracy: 0.0619
# Epoch 3/50
# 254/254 [==============================] - 129s 509ms/step - loss: 3.6346 - accuracy: 0.1848
# Epoch 4/50
# 254/254 [==============================] - 130s 510ms/step - loss: 2.5032 - accuracy: 0.3840
# Epoch 5/50
# 254/254 [==============================] - 129s 509ms/step - loss: 1.5886 - accuracy: 0.5786
# Epoch 6/50
# 254/254 [==============================] - 129s 509ms/step - loss: 1.0260 - accuracy: 0.7232
# Epoch 7/50
# 254/254 [==============================] - 130s 510ms/step - loss: 0.6933 - accuracy: 0.8093
# Epoch 8/50
# 254/254 [==============================] - 129s 509ms/step - loss: 0.4657 - accuracy: 0.8729
# Epoch 9/50
# 254/254 [==============================] - 129s 508ms/step - loss: 0.3250 - accuracy: 0.9130
# Epoch 10/50
# 254/254 [==============================] - 130s 510ms/step - loss: 0.2342 - accuracy: 0.9386
# Epoch 11/50
# 254/254 [==============================] - 130s 511ms/step - loss: 0.1766 - accuracy: 0.9566
# Epoch 12/50
# 254/254 [==============================] - 130s 510ms/step - loss: 0.1293 - accuracy: 0.9703
# Epoch 13/50
# 254/254 [==============================] - 129s 510ms/step - loss: 0.1099 - accuracy: 0.9726
# Epoch 14/50
# 254/254 [==============================] - 129s 509ms/step - loss: 0.0793 - accuracy: 0.9831
# Epoch 15/50
# 254/254 [==============================] - 129s 508ms/step - loss: 0.0611 - accuracy: 0.9881
# Epoch 16/50
# 254/254 [==============================] - 130s 510ms/step - loss: 0.0569 - accuracy: 0.9876
# Epoch 17/50
# 254/254 [==============================] - 130s 511ms/step - loss: 0.0477 - accuracy: 0.9902
# Epoch 18/50
# 254/254 [==============================] - 130s 510ms/step - loss: 0.0381 - accuracy: 0.9920
# Epoch 19/50
# 254/254 [==============================] - 130s 510ms/step - loss: 0.0340 - accuracy: 0.9938
# Epoch 20/50
# 254/254 [==============================] - 129s 510ms/step - loss: 0.0322 - accuracy: 0.9930
# Epoch 21/50
# 254/254 [==============================] - 129s 510ms/step - loss: 0.0308 - accuracy: 0.9935
# Epoch 22/50
# 254/254 [==============================] - 130s 510ms/step - loss: 0.0264 - accuracy: 0.9942
# Epoch 23/50
# 254/254 [==============================] - 129s 510ms/step - loss: 0.0244 - accuracy: 0.9961
# Epoch 24/50
# 254/254 [==============================] - 130s 510ms/step - loss: 0.0232 - accuracy: 0.9954
# Epoch 25/50
# 254/254 [==============================] - 130s 510ms/step - loss: 0.0194 - accuracy: 0.9963
# Epoch 26/50
# 254/254 [==============================] - 130s 511ms/step - loss: 0.0174 - accuracy: 0.9966
# Epoch 27/50
# 254/254 [==============================] - 129s 509ms/step - loss: 0.0180 - accuracy: 0.9951
# Epoch 28/50
# 254/254 [==============================] - 129s 510ms/step - loss: 0.0150 - accuracy: 0.9968
# Epoch 29/50
# 254/254 [==============================] - 130s 511ms/step - loss: 0.0158 - accuracy: 0.9969
# Epoch 30/50
# 254/254 [==============================] - 130s 511ms/step - loss: 0.0162 - accuracy: 0.9968
# Epoch 31/50
# 254/254 [==============================] - 130s 511ms/step - loss: 0.0127 - accuracy: 0.9975
# Epoch 32/50
# 254/254 [==============================] - 130s 511ms/step - loss: 0.0145 - accuracy: 0.9963
# Epoch 33/50
# 254/254 [==============================] - 130s 510ms/step - loss: 0.0109 - accuracy: 0.9977
# Epoch 34/50
# 254/254 [==============================] - 130s 512ms/step - loss: 0.0123 - accuracy: 0.9970
# Epoch 35/50
# 254/254 [==============================] - 129s 510ms/step - loss: 0.0109 - accuracy: 0.9977
# Epoch 36/50
# 254/254 [==============================] - 130s 510ms/step - loss: 0.0106 - accuracy: 0.9973
# Epoch 37/50
# 254/254 [==============================] - 129s 509ms/step - loss: 0.0110 - accuracy: 0.9970
# Epoch 38/50
# 254/254 [==============================] - 129s 509ms/step - loss: 0.0087 - accuracy: 0.9979
# Epoch 39/50
# 254/254 [==============================] - 130s 510ms/step - loss: 0.0113 - accuracy: 0.9973
# Epoch 40/50
# 254/254 [==============================] - 130s 510ms/step - loss: 0.0107 - accuracy: 0.9974
# Epoch 41/50
# 254/254 [==============================] - 130s 511ms/step - loss: 0.0090 - accuracy: 0.9979
# Epoch 42/50
# 254/254 [==============================] - 130s 510ms/step - loss: 0.0099 - accuracy: 0.9970
# Epoch 43/50
# 254/254 [==============================] - 129s 509ms/step - loss: 0.0084 - accuracy: 0.9980
# Epoch 44/50
# 254/254 [==============================] - 130s 510ms/step - loss: 0.0098 - accuracy: 0.9977
# Epoch 45/50
# 254/254 [==============================] - 129s 510ms/step - loss: 0.0089 - accuracy: 0.9974
# Epoch 46/50
# 254/254 [==============================] - 130s 511ms/step - loss: 0.0104 - accuracy: 0.9975
# Epoch 47/50
# 254/254 [==============================] - 130s 511ms/step - loss: 0.0078 - accuracy: 0.9983
# Epoch 48/50
# 254/254 [==============================] - 129s 509ms/step - loss: 0.0076 - accuracy: 0.9982
# Epoch 49/50
# 254/254 [==============================] - 129s 509ms/step - loss: 0.0090 - accuracy: 0.9970
# Epoch 50/50
# 254/254 [==============================] - 130s 511ms/step - loss: 0.0083 - accuracy: 0.9977
# 252/252 [==============================] - 60s 237ms/step
# Test accuracy on iterations is  84.30543464743191

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(test.category, test.Prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92        44
#            1       0.63      0.69      0.66        32
#            2       0.75      0.88      0.81        43
#            3       0.95      0.90      0.93        42
#            4       0.78      0.80      0.79        40
#            5       0.89      0.91      0.90        44
#            6       1.00      0.79      0.89        39
#            7       0.77      0.60      0.68        45
#            8       0.70      0.76      0.73        41
#            9       0.73      0.58      0.64        33
#           10       0.80      0.84      0.82        38
#           11       0.77      0.83      0.80        36
#           12       0.66      0.85      0.74        41
#           13       0.52      0.52      0.52        42
#           14       0.82      0.93      0.87        43
#           15       0.67      0.65      0.66        43
#           16       0.66      0.82      0.73        40
#           17       0.86      0.71      0.78        42
#           18       0.51      0.57      0.54        40
#           19       0.68      0.93      0.79        46
#           20       0.82      0.74      0.78        42
#           21       0.75      0.50      0.60        42
#           22       0.48      0.74      0.58        39
#           23       0.69      0.80      0.74        45
#           24       0.62      0.67      0.64        39
#           25       0.94      0.94      0.94        34
#           26       0.97      0.86      0.91        35
#           27       0.84      0.90      0.87        41
#           28       0.72      0.74      0.73        42
#           29       0.86      0.78      0.82        41
#           30       0.87      0.61      0.72        44
#           31       0.86      0.88      0.87        41
#           32       1.00      0.83      0.91        42
#           33       0.80      0.84      0.82        44
